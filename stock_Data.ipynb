# %%
# !pip install pandas-datareader
# Out:
# Collecting pandas-datareader
#   Using cached https://files.pythonhosted.org/packages/14/52/accb990baebe0063977f26e02df36aa7eb4015ed4e86f828cd76273cd6f1/pandas_datareader-0.8.1-py2.py3-none-any.whl
# Requirement already satisfied: pandas>=0.21 in c:\users\amelie\anaconda3\envs\tf\lib\site-packages (from pandas-datareader) (0.25.3)
# Collecting lxml
#   Downloading https://files.pythonhosted.org/packages/d9/36/e79b8e112fb63b04b72724954ae5519e740982bec84f66e5eb4a353906ef/lxml-4.5.0-cp37-cp37m-win_amd64.whl (3.7MB)
# Collecting requests>=2.3.0
#   Downloading https://files.pythonhosted.org/packages/1a/70/1935c770cb3be6e3a8b78ced23d7e0f3b187f5cbfab4749523ed65d7c9b1/requests-2.23.0-py2.py3-none-any.whl (58kB)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\amelie\anaconda3\envs\tf\lib\site-packages (from pandas>=0.21->pandas-datareader) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\amelie\anaconda3\envs\tf\lib\site-packages (from pandas>=0.21->pandas-datareader) (2019.3)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\amelie\anaconda3\envs\tf\lib\site-packages (from pandas>=0.21->pandas-datareader) (1.17.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\amelie\anaconda3\envs\tf\lib\site-packages (from requests>=2.3.0->pandas-datareader) (2019.11.28)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading https://files.pythonhosted.org/packages/e8/74/6e4f91745020f967d09332bb2b8b9b10090957334692eb88ea4afe91b77f/urllib3-1.25.8-py2.py3-none-any.whl (125kB)
# Collecting idna<3,>=2.5
#   Downloading https://files.pythonhosted.org/packages/89/e3/afebe61c546d18fb1709a61bee788254b40e736cff7271c7de5de2dc4128/idna-2.9-py2.py3-none-any.whl (58kB)
# Collecting chardet<4,>=3.0.2
#   Using cached https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.5 in c:\users\amelie\anaconda3\envs\tf\lib\site-packages (from python-dateutil>=2.6.1->pandas>=0.21->pandas-datareader) (1.13.0)
# Installing collected packages: lxml, urllib3, idna, chardet, requests, pandas-datareader
# Successfully installed chardet-3.0.4 idna-2.9 lxml-4.5.0 pandas-datareader-0.8.1 requests-2.23.0 urllib3-1.25.8

# %%
from pandas_datareader import data as pdr

samsung = pdr.get_data_yahoo('005930.KS')
samsung.head()
# Out:
#                High      Low     Open    Close      Volume   Adj Close
# Date
# 2015-04-13  29820.0  29360.0  29580.0  29580.0  10293300.0  286.857361
# 2015-04-14  29700.0  29300.0  29700.0  29480.0   9429750.0  285.887604
# 2015-04-15  29400.0  28540.0  29200.0  28920.0  13551050.0  280.456970
# 2015-04-16  29540.0  28940.0  29240.0  29540.0  10762350.0  286.469482
# 2015-04-17  29560.0  28940.0  29540.0  29000.0  10172300.0  281.232727

# %%
samsung.tail()
# Out:
#                High      Low     Open    Close      Volume  Adj Close
# Date
# 2020-03-09  56500.0  56500.0  56500.0  56500.0         0.0    56500.0
# 2020-03-10  54900.0  53700.0  53800.0  54600.0  32106554.0    54600.0
# 2020-03-11  54400.0  52000.0  54300.0  52100.0  45707281.0    52100.0
# 2020-03-12  52100.0  52100.0  52100.0  52100.0         0.0    52100.0
# 2020-04-10  49250.0  48650.0  48950.0  49250.0  17761278.0    49250.0

# %%
# 일정 기간동안
from datetime import datetime

start = datetime(2017,1,20)
end = datetime(2019,12,31)

df_samsung = pdr.DataReader('005930.KS', 'yahoo', start, end)

# %%
df_samsung.tail()
# Out:
#                High      Low     Open    Close      Volume  Adj Close
# Date
# 2019-12-23  56400.0  55100.0  56100.0  55500.0   9839252.0    55500.0
# 2019-12-24  55700.0  54800.0  55600.0  55000.0  11868463.0    55000.0
# 2019-12-26  55400.0  54400.0  54700.0  55400.0   9645034.0    55400.0
# 2019-12-27  56900.0  55500.0  55700.0  56500.0  12313056.0    56500.0
# 2019-12-30  56600.0  55700.0  56200.0  55800.0   8356767.0    55800.0

# %%
df_samsung['Close'].plot(figsize=(15,5))

# %%
import pandas_datareader.data as web
from matplotlib.pyplot import imshow

# %%
# 금융 시계열 데이터 로드
sp500 = web.DataReader('^GSPC', data_source = 'yahoo', start = '1/20/2017', end = '12/31/2019')
dow30 = web.DataReader('^DJI', data_source = 'yahoo', start = '1/20/2017', end = '12/31/2019')
nasdaq = web.DataReader('^IXIC', data_source = 'yahoo', start = '1/20/2017', end = '12/31/2019')

# %%
sp500['Close'].plot(grid=True, figsize=(15, 5))
dow30['Close'].plot(grid=True, figsize=(15, 5))
nasdaq['Close'].plot(grid=True, figsize=(15, 5))
